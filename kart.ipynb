# %%
arr = [1,2]

# %%
print(arr)
# Out:
# [1, 2]

# %%
arr?
# Out:
# Type:        list
# String form: [1, 2]
# Length:      2
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
import numpy as np

# %%
np.array(arr)
# Out:
# array([1, 2])

# %%
arr.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_76/464376922.py in <module>
# ----> 1 arr.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
arr_np = np.array(arr)

# %%
arr_np.shape
# Out:
# (2,)

# %%
shape = (1,2,3)
#rand_tensor = np.rand(shape)
ones_tensor = np.ones(shape)
zeros_tensor = np.zeros(shape)

#print(f"Random Tensor: \n {rand_tensor} \n")
print(f"Ones Tensor: \n {ones_tensor} \n")
print(f"Zeros Tensor: \n {zeros_tensor}")
# Out:
# Ones Tensor:
#  [[[1. 1. 1.]
#   [1. 1. 1.]]]
#
# Zeros Tensor:
#  [[[0. 0. 0.]
#   [0. 0. 0.]]]
